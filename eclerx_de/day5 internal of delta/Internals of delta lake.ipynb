-- %% [markdown]
-- Internals of delta lake
--
--   parquet (data files) + delta logs
--
--   delta log in form of below format
--   1. crc
--   2. json
--   3. checkpoint
--
-- Internal of iceberg
--
--   parquet (data files) + metadata files
--   delta log in form of below format
--   1 Json
--   2.Parquet
