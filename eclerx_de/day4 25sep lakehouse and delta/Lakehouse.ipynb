# %% [markdown]
# **Data warehouse:   **             **Data Lake: **                                **Lakehouse: **
# - Only structure data              - structure/unstructure,semi structure       - structure/unstructure,semi structure
# - schema on write                  - schema on Read                             - schema on Read
# - support ACID transaction         - Minimal support to ACID transaction        - support ACID transaction
# - does not corrupt system          - Leave system in Corrupt state              - does not corrupt system
