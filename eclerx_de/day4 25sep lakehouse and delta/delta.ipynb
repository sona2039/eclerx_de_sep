-- %%
%sql
 create table dev.demo.emp(id int, name string);
 insert into dev.demo.emp values (1,'Naval');

-- %%
desc extended dev.demo.emp -- show column heardr name with data types

-- %%
desc detail dev.demo.emp -- show size of tables in bytes, numFiles, type of table, partition columns, clustering columns

-- %%
desc history dev.demo.emp  -- shows the history of the operation done on table

-- %%
create table emp_ice(id int, name string, age int) using iceberg ;

desc extended emp_ice

-- %%
SHOW SCHEMAS IN dev

-- %%
%sql
show tables in dev.demo
