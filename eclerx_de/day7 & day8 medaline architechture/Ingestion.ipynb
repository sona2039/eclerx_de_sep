# %%
# %run "/Workspace/Users/sona2039@gmail.com/1.eclerx_de/day7 medaline architechture/Include"

# %%
dbutils.widgets.text("file_name","")
dbutils.widgets.text("catalog","")
dbutils.widgets.text("schema","")
dbutils.widgets.text("table_name","")

# %%
file_name=dbutils.widgets.get("file_name")
catalog=dbutils.widgets.get("catalog")
schema=dbutils.widgets.get("schema")
table_name=dbutils.widgets.get("table_name")

# %%
# %python
#extracting
df = spark.read.csv(f"{input_path}{file_name}",header=True,inferSchema=True)

# add ingestion_date col
spf = add_ingetion_col(df)

# save to table
spf.write.mode("overwrite").saveAsTable(f"{catalog}.{schema}.{table_name}")
