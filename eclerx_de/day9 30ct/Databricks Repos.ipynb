# %%
github
1. create new repo with readme file in github and copy the url

databricks
2. create a git folder and paste the url
3. configure git creditional


and we commit all the folder and files

# %%
today session we discussed about
cli
compute
repos
