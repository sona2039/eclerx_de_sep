# %%
# %scala

control plan (databricks account):databricks account
  1. compute orchestraction 
  2. Unity catelog (goverance) 
  3. jobs and pipelines 
  4. Serverless compute
  5. notepad and queries 
  6. UI   

data plan(cloud account):(azure, GC, AWS)
1.classic compute 
2.storage bucket
