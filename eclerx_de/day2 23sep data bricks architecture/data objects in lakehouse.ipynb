# %%
Catlog
schema/Database

Tables/View ,Volume, Function ,modeles , SP

create using 
1 UI 
2 Sql syntax

# %%
# %sql
create catalog dev

# %%
# %sql
use catalog dev;
use schema demo;

# %%
# %sql
CREATE TABLE dev.demo.sample (
  id int,
  Name STRING
)

# %%
# %sql
insert into sample values (1,'john')

# %%
# %sql
select * from sample

# %%
# %sql
Create or replace table dev.demo.sales_transactions as
select * from samples.bakehouse.sales_transactions

# %%
# %sql
select sum(totalprice) as sum from samples.bakehouse.sales_transactions
